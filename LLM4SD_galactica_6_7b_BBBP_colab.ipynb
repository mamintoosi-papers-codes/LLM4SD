# %%
# Auto-setup when running on Google Colab
import os
if 'google.colab' in str(get_ipython()) and not os.path.exists('/content/LLM4SD'):
    # !git clone -q https://github.com/mamintoosi-papers-codes/LLM4SD.git /content/LLM4SD
    # !pip --quiet install -r /content/LLM4SD/requirements.txt
    # %cd LLM4SD
    # !curl -fsSL https://ollama.com/install.sh | sh  # نصب Ollama
    # !ollama pull falcon:7b  # دانلود مدل
    # !ollama run falcon:7b "چرا آسمان آبی است؟"  # اجرای مدل
# Out:
# /content/LLM4SD

# %%
# !pip --quiet install -r /content/LLM4SD/requirements.txt

# %%
# !pip install transformers torch accelerate bitsandbytes safetensors

# %%
# %cd LLM4SD
# Out:
# /content/LLM4SD

# %%
# **Step 1:** Generate prior knowledge and data knowledge prompt files
print("Processing Step 1: Generating Prompt files...")
# %run create_prompt.py --task synthesize
# Out:
# Processing Step 1: Generating Prompt files...

# %%
# %run create_prompt.py --task inference

# %%
# **Step 2:** Knowledge synthesis for BBBP dataset
print("Processing Step 2: LLM for Scientific Synthesis")
# %run synthesize.py --dataset bbbp --subtask "" --model galactica-6.7b --output_folder "synthesize_model_response"
# Out:
# Processing Step 2: LLM for Scientific Synthesis
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Device set to use cuda:0
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:631: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.5` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# Extracting bbbp_small dataset prior knowledge prompt ....
# Below is an instruction that describes a task. Write a response that appropriately completes the request.
#
# ### Instruction:
# Assumed you are an experienced chemist. Please come up with 20 rules that you think are very important to predict if a molecule is blood brain barrier permeable (BBBP). Each rule is either about the structure or property of molecules. Each rule starts with 'Calculate....' and don't explain, be short and within 5 words.
#
# ### Response:
#
# 1. Calculate the octanol-water partition coefficient (logP) of the molecule.
# 2. Check for the presence of polar functional groups such as hydroxyl, amino, and carbonyl groups.
# 3. Calculate the number of hydrogen bond donors and acceptors in the molecule.
# 4. Check for the presence of aromatic rings.
# 5. Calculate the molecular weight of the molecule.
# 6. Check for the presence of ionizable functional groups.
# 7. Calculate the polar surface area (PSA) of the molecule.
# 8. Check for the presence of flexible rings.
# 9. Calculate the number of rotatable bonds in the molecule.
# 10. Check for the presence of chiral centers.
# 11. Calculate the number of hydrogen bond donors and acceptors in the molecule.
# 12. Check for the presence of ring systems.
# 13. Calculate the number of aromatic rings in the molecule.
# 14. Check for the presence of functional groups that can form hydrogen bonds with water.
# 15. Calculate the number of hydrogen bond acceptors in the molecule.
# 16. Check for the presence of functional groups that can form hydrogen bonds with other molecules.
# 17. Calculate the number of hydrogen bond donors in the molecule.
# 18. Check for the presence of functional groups that can form hydrogen bonds with other molecules.
# 19. Calculate the number of hydrogen bond acceptors in the molecule.
# 20. Check for the presence of functional groups that can form hydrogen bonds with other molecules.
# Synthesize/Time elapsed: 162.14401030540466 seconds

# %%
# **Step 3:** Knowledge inference for BBBP dataset
print("Processing Step 3: LLM for Scientific Inference")
# %run inference.py --dataset bbbp --subtask "" --model galactica-6.7b --list_num 30 --output_folder "inference_model_response"
# Out:
# Processing Step 3: LLM for Scientific Inference
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/161 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.14M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/96.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/800 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/47.2k [00:00<?, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/9.93G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/7.53G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/45.1k [00:00<?, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# pytorch_model-00001-of-00003.bin:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# pytorch_model-00003-of-00003.bin:   0%|          | 0.00/7.53G [00:00<?, ?B/s]
# pytorch_model-00002-of-00003.bin:   0%|          | 0.00/9.93G [00:00<?, ?B/s]
# The argument `trust_remote_code` is to be used with Auto classes. It has no effect here and is ignored.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /content/LLM4SD/inference.py in <module>
#     267     args = parser.parse_args()
#     268
# --> 269     main()
#
# /content/LLM4SD/inference.py in main()
#     227     smile_label_list = load_dataset(train_file_path)
#     228
# --> 229     tokenizer, pipeline = get_hf_tokenizer_pipeline(args.model)
#     230     dk_prompt = get_inference_prompt()
#     231
#
# /content/LLM4SD/inference.py in get_hf_tokenizer_pipeline(model, is_8bit)
#      65         model_kwargs['quantization_config'] = quantization_config
#      66         tokenizer = AutoTokenizer.from_pretrained(hf_model, use_fast=False, padding_side="left", trust_remote_code=True)
# ---> 67         pipeline = transformers.pipeline("text-generation", model=hf_model, tokenizer=tokenizer,
#      68                                          torch_dtype=torch.float16, trust_remote_code=True, use_fast=False,
#      69                                          device_map='auto', model_kwargs=model_kwargs)
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     940     if isinstance(model, str) or framework is None:
#     941         model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# --> 942         framework, model = infer_framework_load_model(
#     943             adapter_path if adapter_path is not None else model,
#     944             model_classes=model_classes,
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/base.py in infer_framework_load_model(model, config, model_classes, task, framework, **model_kwargs)
#     302             for class_name, trace in all_traceback.items():
#     303                 error += f"while loading with {class_name}, an error is thrown:\n{trace}\n"
# --> 304             raise ValueError(
#     305                 f"Could not load model {model} with any of the following classes: {class_tuple}. See the original errors:\n\n{error}\n"
#     306             )
#
# ValueError: Could not load model GeorgiaTechResearchInstitute/galactica-6.7b-evol-instruct-70k with any of the following classes: (<class 'transformers.models.auto.modeling_auto.AutoModelForCausalLM'>, <class 'transformers.models.auto.modeling_tf_auto.TFAutoModelForCausalLM'>, <class 'transformers.models.opt.modeling_opt.OPTForCausalLM'>, <class 'transformers.models.opt.modeling_tf_opt.TFOPTForCausalLM'>). See the original errors:
#
# while loading with AutoModelForCausalLM, an error is thrown:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/transformers/pipelines/base.py", line 291, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py", line 571, in from_pretrained
#     return model_class.from_pretrained(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py", line 279, in _wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py", line 4399, in from_pretrained
#     ) = cls._load_pretrained_model(
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py", line 4736, in _load_pretrained_model
#     raise ValueError(
# ValueError: The current `device_map` had weights offloaded to the disk. Please provide an `offload_folder` for them. Alternatively, make sure you have `safetensors` installed if the model you are using offers the weights in this format.
#
# while loading with TFAutoModelForCausalLM, an error is thrown:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/transformers/pipelines/base.py", line 291, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py", line 571, in from_pretrained
#     return model_class.from_pretrained(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/modeling_tf_utils.py", line 2859, in from_pretrained
#     raise EnvironmentError(
# OSError: GeorgiaTechResearchInstitute/galactica-6.7b-evol-instruct-70k does not appear to have a file named pytorch_model.bin, tf_model.h5 or model.ckpt
#
# while loading with OPTForCausalLM, an error is thrown:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/transformers/pipelines/base.py", line 291, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py", line 279, in _wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py", line 4399, in from_pretrained
#     ) = cls._load_pretrained_model(
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py", line 4736, in _load_pretrained_model
#     raise ValueError(
# ValueError: The current `device_map` had weights offloaded to the disk. Please provide an `offload_folder` for them. Alternatively, make sure you have `safetensors` installed if the model you are using offers the weights in this format.
#
# while loading with TFOPTForCausalLM, an error is thrown:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/transformers/pipelines/base.py", line 291, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/modeling_tf_utils.py", line 2859, in from_pretrained
#     raise EnvironmentError(
# OSError: GeorgiaTechResearchInstitute/galactica-6.7b-evol-instruct-70k does not appear to have a file named pytorch_model.bin, tf_model.h5 or model.ckpt

# %%
# !du -h --max-depth=1 /root/.cache/huggingface
# Out:
# 52G	/root/.cache/huggingface/hub
# 52G	/root/.cache/huggingface

# %%
# **Step 3:** Knowledge inference for BBBP dataset
print("Processing Step 3: LLM for Scientific Inference")
# %run inference.py --dataset bbbp --subtask "" --model galactica-6.7b --list_num 30 --output_folder "inference_model_response"

# %%
# **Step 4:** Summarizing inference rules using GPT-4
print("Processing Step 4: Summarizing Rules from GPT-4")
API_KEY = ""  # Set your OpenAI API Key before running
# %run summarize_rules.py --input_model_folder galactica-6.7b --dataset bbbp --subtask "" --list_num 30 --api_key $API_KEY --output_folder "summarized_inference_rules"

# %%
# **Step 5:** Interpretable model training and evaluation
print("Processing Step 5: Interpretable Model Training and Evaluation")
# %run code_gen_and_eval.py --dataset bbbp --subtask "" --model galactica-6.7b --knowledge_type "synthesize" --api_key $API_KEY --output_dir "llm4sd_results" --code_gen_folder "llm4sd_code_generation"

# %%
# %run code_gen_and_eval.py --dataset bbbp --subtask "" --model galactica-6.7b --knowledge_type "inference" --list_num 30 --api_key $API_KEY --output_dir "llm4sd_results" --code_gen_folder "llm4sd_code_generation"

# %%
# %run code_gen_and_eval.py --dataset bbbp --subtask "" --model galactica-6.7b --knowledge_type "all" --list_num 30 --api_key $API_KEY --output_dir "llm4sd_results" --code_gen_folder "llm4sd_code_generation"

print("Processing completed for BBBP dataset.")
